# %%
#B問題　デバッグ用
from collections import Counter

def untildeath(deathlist,direction):
    if direction == "R" and deathlist[1] < W:
        deathlist[1] += 1
    elif direction == "L" and deathlist[0] < W:
        deathlist[0] += 1
    elif direction == "U" and deathlist[3] < H:
        deathlist[3] += 1
    elif direction == "D" and deathlist[2] < H:
        deathlist[2] += 1
    return deathlist

def possible_step(killinglist, direction):
    if direction == "R":
        killinglist[0] += 1
    elif direction == "L":
        killinglist[1] += 1
    elif direction == "U":
        killinglist[2] += 1
    elif direction == "D":
        killinglist[3] += 1
    return killinglist

def isDead(killinglist, deathlist):
    for i in range(4):
        if killinglist[i] - deathlist[i] >=0:
            return True
    print("alive")
    return False
#入力1
H=2
W=3
N=3
init_r=2
init_c=2
S="RRL"
T="LUD"

#入力2
# H=4
# W=3
# N=5
# init_r=2
# init_c=2
# S="UDRRR"
# T="LLDUD"

#読み込み
# H,W,N = map(int,input().split())
# init_r,init_c = map(int,input().split())
# S = input()
# T = input()

#こま死亡までの最大ステップ数 K_R,L,U,D
K_R = (W - init_c + 1)
K_L = init_c
K_U = init_r
K_D = (H - init_r + 1)
# check
# print(K_R,K_L,K_U,K_D)
# print(Counter(S))
deathlist = [K_R, K_L, K_U, K_D]
killinglist = [0,0,0,0]
ans = "YES"
for i in range(N):
    print(i)
    direction = S[i]
    killinglist = possible_step(killinglist, direction)
    print(killinglist)
    if isDead(killinglist, deathlist):
        ans = "NO"
        break
    direction = T[i]
    deathlist = untildeath(deathlist, direction)
    print(deathlist)
    
print(ans)

#listはrludの順で
# i ステップ目までの絶対死亡するステップ数を数える
# Out:
# 0
# [1, 0, 0, 0]
# alive
# [3, 2, 2, 1]
# 1
# [2, 0, 0, 0]
# alive
# [3, 2, 2, 2]
# 2
# [2, 1, 0, 0]
# alive
# [3, 2, 2, 2]
# YES

# %%
from collections import Counter
S = "UDRRR"
S[0]
# Out:
# 'U'

# %%
dict(Counter(S))
# Out:
# {'U': 1, 'D': 1, 'R': 3}

# %%
#B問題 提出用
from collections import Counter

def untildeath(deathlist,direction):
    if direction == "R" and deathlist[1] < W:
        deathlist[1] += 1
    elif direction == "L" and deathlist[0] < W:
        deathlist[0] += 1
    elif direction == "U" and deathlist[3] < H:
        deathlist[3] += 1
    elif direction == "D" and deathlist[2] < H:
        deathlist[2] += 1
    return deathlist

def possible_step(killinglist, direction):
    if direction == "R":
        killinglist[0] += 1
    elif direction == "L":
        killinglist[1] += 1
    elif direction == "U":
        killinglist[2] += 1
    elif direction == "D":
        killinglist[3] += 1
    return killinglist

def isDead(killinglist, deathlist):
    for i in range(4):
        if killinglist[i] - deathlist[i] >=0:
            return True
#     print("alive")
    return False

#入力2
# H=4
# W=3
# N=5
# init_r=2
# init_c=2
# S="UDRRR"
# T="LLDUD"

#読み込み
H,W,N = map(int,input().split())
init_r,init_c = map(int,input().split())
S = input()
T = input()

#こま死亡までの最大ステップ数 K_R,L,U,D
K_R = (W - init_c + 1)
K_L = init_c
K_U = init_r
K_D = (H - init_r + 1)
# check
# print(K_R,K_L,K_U,K_D)
# print(Counter(S))
deathlist = [K_R, K_L, K_U, K_D]
killinglist = [0,0,0,0]
ans = "YES"
for i in range(N):
#     print(i)
    direction = S[i]
    killinglist = possible_step(killinglist, direction)
#     print(killinglist)
    if isDead(killinglist, deathlist):
        ans = "NO"
        break
    direction = T[i]
    deathlist = untildeath(deathlist, direction)
#     print(deathlist)
    
print(ans)

#listはrludの順で
# i ステップ目までの絶対死亡するステップ数を数える
# Out:
# NO

# %%
# 変更後　デバッグ用

#入力1
H=2
W=3
N=3
init_r=2
init_c=2
S="RRL"
T="LUD"

#入力2
# H=4
# W=3
# N=5
# init_r=2
# init_c=2
# S="UDRRR"
# T="LLDUD"


# H,W,N = map(int,input().split())
# init_r,init_c = map(int,input().split())
# S = input()
# T = input()

r = init_c
l = init_c
u = init_r
d = init_r

print(r,l,u,d)

for i in range(N):
    print(i)
    #killer's turn
    
    direction = S[i]
    if direction == "R":
        if r == W:
            ans = "NO"
            break
        else:
            r +=1
    elif direction == "L":
        if l == 1:
            ans = "NO"
            break
        else:
            l +=1
    elif direction == "U":
        if u == 1:
            ans = "NO"
            break
        else:
            u +=1
    elif direction == "D":
        if d == H:
            ans = "NO"
            break
        else:
            d +=1
            
    print(r,l,u,d)

    #savor's turn
    direction = T[i]
    if direction == "R" and l != W:
        l += 1
    elif direction == "L" and r != 1:
        r -= 1
    elif direction == "U" and d != 1:
        d -= 1
    elif direction == "D" and u != H:
        u += 1
    print(r,l,u,d)



    
print(ans)
# Out:
# 2 2 2 2
# 0
# 3 2 2 2
# 2 2 2 2
# 1
# 3 2 2 2
# 3 2 2 1
# 2
# 3 3 2 1
# 3 3 2 1
# NO

# %%
 0!= 1
# Out:
# True

# %%
# 変更後2 後ろから数える　デバッグ用

# 入力1
# H=2
# W=3
# N=3
# init_r=2
# init_c=2
# S="RRL"
# T="LUD"

# 入力2
# H=4
# W=3
# N=5
# init_r=2
# init_c=2
# S="UDRRR"
# T="LLDUD"

#入力3
H = 5
W = 6
N = 11
init_r = 2
init_c = 1
S ="RLDRRUDDLRL"
T ="URRDRLLDLRD"

# H,W,N = map(int,input().split())
# init_r,init_c = map(int,input().split())
# S = input()
# T = input()

r = W+1
l = 0
u = 0
d = H+1

print(r,l,u,d)
ans = "YES"

for i in range(N):
    t = N-1-i
    print("index:",t)
    #savor's turn
    direction = T[t]
    print(direction)
    if direction == "R" and l != 0:
        l -= 1
    elif direction == "L" and r != W+1:
        r += 1
    elif direction == "U" and d != H+1:
        d += 1
    elif direction == "D" and u != 0:
        u -= 1
    print(r,l,u,d)
    
#     killer's turn
    t = N-1-i
    direction = S[t]
    print(direction)
    if direction == "R":
        r -=1
        if r == 1:
            ans = "NO"
            break
    elif direction == "L":
        l +=1
        if l == W:
            ans = "NO"
            break
    elif direction == "U":
        u +=1
        if u == H:
            ans = "NO"
            break
    elif direction == "D":
        d -=1
        if d == 1:
            ans = "NO"
            break
    if r <= l:
        ans = "NO"
        break    
    if d <= u:
        ans = "NO"
        break
        
#     3 >= 2
# 2 <= 3
    print(r,l,u,d)
#     print(r,l)
#     print(r,l)

if init_c <= l or init_c >= r:
    ans = "NO"

        
if init_r <= u or init_r >= d:
    ans = "NO"




    
print(ans)
# Out:
# 7 0 0 6
# index: 10
# D
# 7 0 0 6
# L
# 7 1 0 6
# index: 9
# R
# 7 0 0 6
# R
# 6 0 0 6
# index: 8
# L
# 7 0 0 6
# L
# 7 1 0 6
# index: 7
# D
# 7 1 0 6
# D
# 7 1 0 5
# index: 6
# L
# 7 1 0 5
# D
# 7 1 0 4
# index: 5
# L
# 7 1 0 4
# U
# 7 1 1 4
# index: 4
# R
# 7 0 1 4
# R
# 6 0 1 4
# index: 3
# D
# 6 0 0 4
# R
# 5 0 0 4
# index: 2
# R
# 5 0 0 4
# D
# 5 0 0 3
# index: 1
# R
# 5 0 0 3
# L
# 5 1 0 3
# index: 0
# U
# 5 1 0 4
# R
# 4 1 0 4
# NO

# %%
# 変更後2 後ろから数える　デバッグ用

H,W,N = map(int,input().split())
init_r,init_c = map(int,input().split())
S = input()
T = input()

r = W+1
l = 0
u = 0
d = H+1

# print(r,l,u,d)
ans = "YES"

for i in range(N):
    t = N-1-i
#     print("index:",t)
    #savor's turn
    direction = T[t]
#     print(direction)
    if direction == "R" and l != 0:
        l -= 1
    elif direction == "L" and r != W+1:
        r += 1
    elif direction == "U" and d != H+1:
        d += 1
    elif direction == "D" and u != 0:
        u -= 1
#     print(r,l,u,d)
    
#     killer's turn
    t = N-1-i
    direction = S[t]
#     print(direction)
    if direction == "R":
        r -=1
        if r == 1:
            ans = "NO"
            break
    elif direction == "L":
        l +=1
        if l == W:
            ans = "NO"
            break
    elif direction == "U":
        u +=1
        if u == H:
            ans = "NO"
            break
    elif direction == "D":
        d -=1
        if d == 1:
            ans = "NO"
            break
    if r <= l:
        ans = "NO"
        break    
    if d <= u:
        ans = "NO"
        break
        
#     3 >= 2
# 2 <= 3
#     print(r,l,u,d)
#     print(r,l)
#     print(r,l)

if init_c <= l or init_c >= r:
    ans = "NO"

        
if init_r <= u or init_r >= d:
    ans = "NO"




    
print(ans)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-4.2.0/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# ~/.pyenv/versions/anaconda3-4.2.0/envs/py36/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/.pyenv/versions/anaconda3-4.2.0/envs/py36/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     466         """
# --> 467         parts = [self.recv(flags, copy=copy, track=track)]
# ...

# %%
for i in range(N):
    print(N-1-i)
# Out:
# 2
# 1
# 0

# %%
3 >= 2
2 <= 3
# Out:
# True

# %%
3 >= 2
# Out:
# True

# %%
# Out:
#   File "<ipython-input-48-a88ce231611b>", line 1
#     2 =< 3
#        ^
# SyntaxError: invalid syntax

# %%
# H,W,N = map(int,input().split())
# init_r,init_c = map(int,input().split())
# S = input()
# T = input()
H=4
W=3
N=5
init_r=2
init_c=2
S="UDRRR"
T="LLDUD"
print("H =",H)
print("W =",W)
print("N =",N)
print("init_r =",init_r)
print("init_c =",init_c)
print("S =\""+S+"\"")
print("T =\""+T+"\"")
# Out:
# H = 4
# W = 3
# N = 5
# init_r = 2
# init_c = 2
# S ="UDRRR"
# T ="LLDUD"

# %%
S ="RLDRRUDDLRL"
T ="URRDRLLDLRD"
N=11
for i in range(N):
    t = N-1-i
    print(t)
    direction = T[t]
    print(direction)

#     direction = S[t]
#     print(direction)
# Out:
# 10
# D
# 9
# R
# 8
# L
# 7
# D
# 6
# L
# 5
# L
# 4
# R
# 3
# D
# 2
# R
# 1
# R
# 0
# U

# %%
# 変更後2 後ろから数える　デバッグ用

H,W,N = map(int,input().split())
init_r,init_c = map(int,input().split())
S = input()
T = input()

r = W+1
l = 0
u = 0
d = H+1

ans = "YES"

for i in range(N):
    t = N-1-i
    #savor's turn
    direction = T[t]
    if direction == "R" and l != 0:
        l -= 1
    elif direction == "L" and r != W+1:
        r += 1
    elif direction == "U" and d != H+1:
        d += 1
    elif direction == "D" and u != 0:
        u -= 1
        
#     killer's turn
    t = N-1-i
    direction = S[t]
    if direction == "R":
        r -=1
        if r == 1:
            ans = "NO"
            break
    elif direction == "L":
        l +=1
        if l == W:
            ans = "NO"
            break
    elif direction == "U":
        u +=1
        if u == H:
            ans = "NO"
            break
    elif direction == "D":
        d -=1
        if d == 1:
            ans = "NO"
            break
    if r <= l:
        ans = "NO"
        break    
    if d <= u:
        ans = "NO"
        break

if init_c <= l or init_c >= r:
    ans = "NO"
if init_r <= u or init_r >= d:
    ans = "NO"
print(ans)

# %%
#C問題サンプル入力用コード
N = int(input())
#各頂点が繋がってる辺リスト
E = [ [] for _ in range(N)]
for i in range(N-1):
    a,b = map(int, input().split())
    E[a-1].append(b-1)
    E[b-1].append(a-1)
print("N=",N)
print("E=",E)

# %%
#入力1
N= 3
E= [[1], [0, 2], [1]]

#　入力2
N= 6
E= [[1], [0, 2, 3], [1], [1, 5], [5], [3, 4]]

#　入力3
N= 7
E= [[6, 1], [0], [3, 5], [6, 2], [6], [2], [0, 3, 4]]

# %%
N= 3
E= [[1], [0, 2], [1]]

def farthest(s):
    visited = []
    stack = [[s,0]]
    best = [s,0]
    while len(stack)>0:
        print("visited:",visited)
        print("stack:",stack)
        current = stack.pop()#pop(-1)と同じ
        currentPosition = current[0] 
        currentLength = current[1]
        # bestの更新
        if currentLength > best[1]:
            best = [currentPosition, currentLength]
        visited.append(currentPosition)
        # 繋がっているノードのうち未探索の場所を追加
        for position in E[currentPosition]:
            if position not in visited:
                stack.append([position, currentLength+1])
    return best

farthest(0)
# Out:
# visited: []
# stack: [[0, 0]]
# visited: [0]
# stack: [[1, 1]]
# visited: [0, 1]
# stack: [[2, 2]]
# [2, 2]

# %%
# C問題 20分で最長の長さの道の含むノードの数Nに対して
# N%3 == 2ならS, それ以外でFであることまでわかった。
# !!直径rでいうとr%3 ==1 ならS
# しかし、longest path problemはNP hardとか言われた... 
# けど、treeであることを考慮に入れて再検索すると行けた。
# ググり力 = 関連ワードを色々入れて試す力 & 関係なさそうなテーマから早く撤退する

# 木の直径というらしい
# 木DP or 適当に初期点W　→ Wからの最遠点U　→ Uからの最遠点V でUとVの距離でわかるらしい。

# 下記codeはTLEになりました...

N = int(input())
#各頂点が繋がってる辺リスト
E = [ [] for _ in range(N)]
for i in range(N-1):
    a,b = map(int, input().split())
    E[a-1].append(b-1)
    E[b-1].append(a-1)

# #入力1
# N= 3
# E= [[1], [0, 2], [1]]

# #　入力2
# N= 6
# E= [[1], [0, 2, 3], [1], [1, 5], [5], [3, 4]]

# #　入力3
# N= 7
# E= [[6, 1], [0], [3, 5], [6, 2], [6], [2], [0, 3, 4]]


    
def farthest(s):
    visited = []
    stack = [[s,0]]
    best = [s,0]
    while len(stack)>0:
#         print("visited:",visited)
#         print("stack:",stack)
        current = stack.pop()#pop(-1)と同じ
        currentPosition = current[0] 
        currentLength = current[1]
        # bestの更新
        if currentLength > best[1]:
            best = [currentPosition, currentLength]
        visited.append(currentPosition)
        # 繋がっているノードのうち未探索の場所を追加
        for position in E[currentPosition]:
            if position not in visited:
                stack.append([position, currentLength+1])
    return best

# print("u,length:",farthest(0))
u = farthest(0)[0]
best = farthest(u)
# print(best)
# v = best[0]
diameter = best[1]
# print(diameter)
ans = "First"
if diameter % 3 == 1:
    ans = "Second"
print(ans)
# Out:
# First

# %%
# visitedをノードのリストにして管理して
# if position not in visited:
# としたのががクソ重かったらしい。
# visitedを各ノードに対するT/Fで保持したら一発で通った




# カンニングして修正
N = int(input())
#各頂点が繋がってる辺リスト
E = [ [] for _ in range(N)]
for i in range(N-1):
    a,b = map(int, input().split())
    E[a-1].append(b-1)
    E[b-1].append(a-1)

# #入力1
# N= 3
# E= [[1], [0, 2], [1]]

# #　入力2
# N= 6
# E= [[1], [0, 2, 3], [1], [1, 5], [5], [3, 4]]

# #　入力3
# N= 7
# E= [[6, 1], [0], [3, 5], [6, 2], [6], [2], [0, 3, 4]]


    
def farthest(s):
    visited = [False]*N
    stack = [[s,0]]
    best = [s,0]
    while len(stack)>0:
#         print("visited:",visited)
#         print("stack:",stack)
        current = stack.pop()#pop(-1)と同じ
        currentPosition = current[0] 
        currentLength = current[1]
        visited[currentPosition] = True
        # bestの更新
        if currentLength > best[1]:
            best = [currentPosition, currentLength]
        visited.append(currentPosition)
        # 繋がっているノードのうち未探索の場所を追加
        for position in E[currentPosition]:
            if not visited[position]:
                stack.append([position, currentLength+1])
    return best

# print("u,length:",farthest(0))
u = farthest(0)[0]
best = farthest(u)
# print(best)
# v = best[0]
diameter = best[1]
# print(diameter)
ans = "First"
if diameter % 3 == 1:
    ans = "Second"
print(ans)
# Out:
# Second
